# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings

# %%
def label(row):
    return int(row['Topic Cluster Number'][3:])

# %%
df1= pd.read_csv('Instituto Tecnologico de Estudios Superiores de Monterrey.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df1['Institution'] = 'Instituto Tecnologico de Estudios Superiores de Monterrey'
df2= pd.read_csv('Maastricht University.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df2['Institution'] = 'Maastricht University'
df3 = pd.read_csv('National Cheng Kung University.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df3['Institution'] = 'National Cheng Kung University'
df4 = pd.read_csv('Renmin University of China.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df4['Institution'] = 'Renmin University of China'
df5 = pd.read_csv('The Chinese University of Hong Kong, Shenzhen.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df5['Institution'] = 'The Chinese University of Hong Kong, Shenzhen'
df6 = pd.read_csv('Universidade Federal de Minas Gerais.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df6['Institution'] = 'Universidade Federal de Minas Gerais'
df7 = pd.read_csv('University College Dublin.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df['Institution'] = 'University College Dublin'
df8 = pd.read_csv('University of Alberta.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df8['Institution'] = 'University of Alberta'
df9 = pd.read_csv('University of Auckland.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df9['Institution'] = 'University of Auckland'
df10 = pd.read_csv('University of Bergen.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df10['Institution'] = 'University of Bergen'
df11 = pd.read_csv('University of Bristol.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df11['Institution'] = 'University of Bristol'
df12 = pd.read_csv('University of Cape Town.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df12['Institution'] = 'University of Cape Town'
df13 = pd.read_csv('University of Ghana.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df13['Institution'] = 'University of Ghana'
df14 = pd.read_csv('University of Leeds.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df14['Institution'] = 'University of Leeds'
df15 = pd.read_csv('University of Massachusetts.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df15['Institution'] = 'University of Massachusetts'
df16 = pd.read_csv('University of Nairobi.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df16['Institution'] = 'University of Nairobi'
df17 = pd.read_csv('University of Rochester.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df17['Institution'] = 'University of Rochester'
df18 = pd.read_csv('University of Sheffield.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df18['Institution'] = 'University of Sheffield'
df19 = pd.read_csv('University of Southampton.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df19['Institution'] = 'University of Southampton'
df20 = pd.read_csv('University of Sydney.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df20['Institution'] = 'University of Sydney'
df21 = pd.read_csv('University of Western Australia.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df21['Institution'] = 'University of Western Australia'
df22 = pd.read_csv('University of York.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df22['Institution'] = 'University of York'
df23 = pd.read_csv('Zhejiang University.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
df23['Institution'] = 'Zhejiang University'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d36f759fe417> in <module>
#      12 df6['Institution'] = 'Universidade Federal de Minas Gerais'
#      13 df7 = pd.read_csv('University College Dublin.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
# ---> 14 df['Institution'] = 'University College Dublin'
#      15 df8 = pd.read_csv('University of Alberta.csv', encoding='latin1', skiprows=12).sort_values(['Field-Weighted Citation Impact'], ascending=False).head(50).reset_index(drop=True)
#      16 df8['Institution'] = 'University of Alberta'
#
# NameError: name 'df' is not defined

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13,
               df14, df15, df16, df17, df18, df19, df20, df21, df22, df23], sort=False)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8b0b1e5ecfcb> in <module>
# ----> 1 df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13,
#       2                df14, df15, df16, df17, df18, df19, df20, df21, df22, df23], sort=False)
#       3 df
#
# NameError: name 'df8' is not defined

# %%
df_grouped = df.groupby('Topic Cluster Number').agg({'Institution': lambda x : ', '.join(str(v) for v in x)})

# %%
df_final = pd.merge(df_grouped, df, on='Topic Cluster Number', how='outer')

# %%
df_final
# Out:
#      Topic Cluster Number                                      Institution_x  \
# 0                    TC.0  Universidade Federal de Minas Gerais, Universi...
# 1                    TC.0  Universidade Federal de Minas Gerais, Universi...
# 2                    TC.0  Universidade Federal de Minas Gerais, Universi...
# 3                    TC.0  Universidade Federal de Minas Gerais, Universi...
# 4                    TC.0  Universidade Federal de Minas Gerais, Universi...
# 5                    TC.1  National Cheng Kung University, nan, Universit...
# 6                    TC.1  National Cheng Kung University, nan, Universit...
# 7                    TC.1  National Cheng Kung University, nan, Universit...
# 8                    TC.1  National Cheng Kung University, nan, Universit...
# 9                    TC.1  National Cheng Kung University, nan, Universit...
# 10                   TC.1  National Cheng Kung University, nan, Universit...
# ...

# %%
df_final.rename(columns={'Institution_y':'Specific Institution'}, inplace=True)

# %%
df_final.rename(columns={'Institution_x':'Institutions With the Same Topic Number'}, inplace=True)

# %%
df_final
# Out:
#      Topic Cluster Number            Institutions With the Same Topic Number  \
# 0                    TC.0  Universidade Federal de Minas Gerais, Universi...
# 1                    TC.0  Universidade Federal de Minas Gerais, Universi...
# 2                    TC.0  Universidade Federal de Minas Gerais, Universi...
# 3                    TC.0  Universidade Federal de Minas Gerais, Universi...
# 4                    TC.0  Universidade Federal de Minas Gerais, Universi...
# 5                    TC.1  National Cheng Kung University, nan, Universit...
# 6                    TC.1  National Cheng Kung University, nan, Universit...
# 7                    TC.1  National Cheng Kung University, nan, Universit...
# 8                    TC.1  National Cheng Kung University, nan, Universit...
# 9                    TC.1  National Cheng Kung University, nan, Universit...
# 10                   TC.1  National Cheng Kung University, nan, Universit...
# ...

# %%
df = df_final

# %%
df = df.drop_duplicates(subset='Topic Cluster Number')

# %%
df
# Out:
#      Topic Cluster Number                                       Institutions  \
# 0                    TC.0  Universidade Federal de Minas Gerais, Universi...
# 5                    TC.1  National Cheng Kung University, nan, Universit...
# 13                  TC.10                                University of Ghana
# 14                TC.1005                              University of Nairobi
# 15                TC.1009  Instituto Tecnologico de Estudios Superiores d...
# 16                 TC.101                         Renmin University of China
# 17                TC.1014                              University of Alberta
# 18                TC.1015                              University of Nairobi
# 19                TC.1017  Instituto Tecnologico de Estudios Superiores d...
# 21                TC.1018                            University of Sheffield
# 22                 TC.102                            University of Rochester
# ...

# %%
df.to_csv("all_23.csv")

# %%
df['TC#']= df.apply(lambda row: label(row), axis=1)

# %%
df.head()
# Out:
#                                        Topic Cluster Topic Cluster Number  \
# 0                 Neoplasms; Breast Neoplasms; Cells               TC.535
# 1   Optogenetics; Electrophysiology; Microelectrodes               TC.892
# 2  Sustainability; Sustainable Development; Students               TC.879
# 3          Human Engineering; Ergonomics; Automation               TC.588
# 4                        Cells; Neoplasms; Hydrogels               TC.166
#
#    Scholarly Output  Publication share (%) Growth (%)  \
# 0               2.0                   0.03          -
# 1               2.0                   0.03          -
# 2              13.0                   0.19      -16.3
# 3               4.0                   0.04          -
# 4               8.0                   0.04          -
#
#    Field-Weighted Citation Impact  Prominence percentile  TC#
# 0                           16.84                 77.041  535
# 1                           14.70                 72.624  892
# ...

# %%
df_world = pd.read_csv('world_data.csv', encoding='latin1', skiprows=12)

# %%
df_world
# Out:
#                                          Topic Cluster Topic Cluster Number  \
# 0                  Algorithms; Computer Vision; Models                 TC.0
# 1          Photocatalysis; Photocatalysts; Solar Cells                 TC.8
# 2    Cognitive Radio; MIMO Systems; Orthogonal Freq...                 TC.3
# 3    Secondary Batteries; Electric Batteries; Lithi...                TC.30
# 4                Graphene; Carbon Nanotubes; Nanotubes                TC.22
# 5    Electric Potential; Electric Inverters; DC-DC ...                TC.13
# 6                             Galaxies; Stars; Planets                 TC.1
# 7    Electric Power Transmission Networks; Wind Pow...                TC.28
# 8                      Climate Models; Model; Rainfall                 TC.5
# 9    Wireless Sensor Networks; Sensor Nodes; Routin...                TC.27
# 10    Control; Controllers; Linear Matrix Inequalities                 TC.9
# ...

# %%
df_world = df_world[df_world['Topic Cluster Number'].isin(df['Topic Cluster Number'])]

# %%
df = df[df['Topic Cluster Number'].isin(df_world['Topic Cluster Number'])]

# %%
df_world['TC#']= df_world.apply(lambda row: label(row), axis=1)

# %%
df_world
# Out:
#                                          Topic Cluster Topic Cluster Number  \
# 0                  Algorithms; Computer Vision; Models                 TC.0
# 1          Photocatalysis; Photocatalysts; Solar Cells                 TC.8
# 2    Cognitive Radio; MIMO Systems; Orthogonal Freq...                 TC.3
# 3    Secondary Batteries; Electric Batteries; Lithi...                TC.30
# 4                Graphene; Carbon Nanotubes; Nanotubes                TC.22
# 5    Electric Potential; Electric Inverters; DC-DC ...                TC.13
# 6                             Galaxies; Stars; Planets                 TC.1
# 7    Electric Power Transmission Networks; Wind Pow...                TC.28
# 8                      Climate Models; Model; Rainfall                 TC.5
# 9    Wireless Sensor Networks; Sensor Nodes; Routin...                TC.27
# 10    Control; Controllers; Linear Matrix Inequalities                 TC.9
# ...

# %%
df = df.sort_values(['TC#'], ascending=False)
df = df.reset_index(drop=True)
df = df.head(10)

# %%
plt.figure(figsize=(20, 25))
plt.bar(df['Topic Cluster Number'], df['Field-Weighted Citation Impact'])
# Out:
# <BarContainer object of 10 artists>

# %%
df_world = df_world.sort_values(['TC#'], ascending=False)

# %%
df_world.head()
# Out:
#                                          Topic Cluster Topic Cluster Number  \
# 417               Sensors; Accelerometers; Smartphones               TC.880
# 499  Neoplastic Stem Cells; Neoplasms; Breast Neopl...               TC.860
# 430            Ionic Liquids; Eutectics; Negative Ions               TC.847
# 438  Optical Communication; Light Emitting Diodes; ...               TC.796
# 431                         Sarcopenia; Patients; Aged               TC.782
#
#      Scholarly Output  Field-Weighted Citation Impact  Prominence percentile  \
# 417            9932.0                            1.35                 69.813
# 499            8628.0                            1.24                 83.735
# 430            9784.0                            1.30                 92.102
# 438            9678.0                            1.20                 58.434
# 431            9773.0                            1.74                 82.129
#
#      TC#
# 417  880
# 499  860
# 430  847
# ...

# %%
df_world = df_world.reset_index(drop=True)
df_world = df_world.head(10)

# %%
df_world
# Out:
#                                        Topic Cluster Topic Cluster Number  \
# 0               Sensors; Accelerometers; Smartphones               TC.880
# 1  Neoplastic Stem Cells; Neoplasms; Breast Neopl...               TC.860
# 2            Ionic Liquids; Eutectics; Negative Ions               TC.847
# 3  Optical Communication; Light Emitting Diodes; ...               TC.796
# 4                         Sarcopenia; Patients; Aged               TC.782
# 5                Health Literacy; Patients; Internet               TC.717
# 6        Wastes; Solid Wastes; Municipal Solid Waste               TC.703
# 7  Nanoparticles; Metal Nanoparticles; Nanostruct...               TC.700
# 8  Failure Analysis; Bearings (Machine Parts); Ro...               TC.670
# 9                Forest; Deforestation; Conservation               TC.663
#
#    Scholarly Output  Field-Weighted Citation Impact  Prominence percentile  \
# 0            9932.0                            1.35                 69.813
# ...

# %%
plt.figure(figsize=(20, 25))
plt.bar(df_world['Topic Cluster Number'], df_world['Field-Weighted Citation Impact'])
# Out:
# <BarContainer object of 10 artists>
